# %% [markdown]
# # 单卡GPU 进行 ChatGLM3-6B模型 LORA 高效微调
# 本 Cookbook 将带领开发者使用 `AdvertiseGen` 对 ChatGLM3-6B 数据集进行 lora微调，使其具备专业的广告生成能力。
#
# ## 硬件需求
# 显存：24GB及以上（推荐使用30系或A10等sm80架构以上的NVIDIA显卡进行尝试）
# 内存：16GB
# RAM: 2.9 /16 GB
# GPU RAM: 15.5/16.0 GB

# %% [markdown]
# ## 0. 环境检查
# 首先，先检查代码的运行地址，确保运行地址处于 `finetune_demo` 中。
# 并且，确保已经安装了 `requirements.txt`中的依赖。
#
# > 本 demo 中，不需要使用 deepspeed, mpi4py 两个依赖，如果您安装这两个依赖遇到问题，可以不安装这两个依赖。

# %%
# !pwd
# Out:
# /media/zr/Data/Code/ChatGLM3/finetune_demo

# %% [markdown]
# ## 1. 准备数据集
# 我们使用 AdvertiseGen 数据集来进行微调。从 [Google Drive](https://drive.google.com/file/d/13_vf0xRTQsyneRKdD1bZIr93vBGOczrk/view?usp=sharing) 或者 [Tsinghua Cloud](https://cloud.tsinghua.edu.cn/f/b3f119a008264b1cabd1/?dl=1) 下载处理好的 AdvertiseGen 数据集，将解压后的 AdvertiseGen 目录放到本目录的 `/data/` 下, 例如。
# > /media/zr/Data/Code/ChatGLM3/finetune_demo/data/AdvertiseGen

# %%
import json
from typing import Union
from pathlib import Path


def _resolve_path(path: Union[str, Path]) -> Path:
    return Path(path).expanduser().resolve()


def _mkdir(dir_name: Union[str, Path]):
    dir_name = _resolve_path(dir_name)
    if not dir_name.is_dir():
        dir_name.mkdir(parents=True, exist_ok=False)


def convert_adgen(data_dir: Union[str, Path], save_dir: Union[str, Path]):
    def _convert(in_file: Path, out_file: Path):
        _mkdir(out_file.parent)
        with open(in_file, encoding='utf-8') as fin:
            with open(out_file, 'wt', encoding='utf-8') as fout:
                for line in fin:
                    dct = json.loads(line)
                    sample = {'conversations': [{'role': 'user', 'content': dct['content']},
                                                {'role': 'assistant', 'content': dct['summary']}]}
                    fout.write(json.dumps(sample, ensure_ascii=False) + '\n')

    data_dir = _resolve_path(data_dir)
    save_dir = _resolve_path(save_dir)

    train_file = data_dir / 'train.json'
    if train_file.is_file():
        out_file = save_dir / train_file.relative_to(data_dir)
        _convert(train_file, out_file)

    dev_file = data_dir / 'dev.json'
    if dev_file.is_file():
        out_file = save_dir / dev_file.relative_to(data_dir)
        _convert(dev_file, out_file)


convert_adgen('data/AdvertiseGen', 'data/AdvertiseGen_fix')

# %% [markdown]
# ## 2. 使用命令行开始微调,我们使用 lora 进行微调
# 接着，我们仅需要将配置好的参数以命令行的形式传参给程序，就可以使用命令行进行高效微调。

# %%
# !CUDA_VISIBLE_DEVICES=0 \
    NCCL_P2P_DISABLE="1" \
    NCCL_IB_DISABLE="1" \
    python finetune_hf.py \
    data/AdvertiseGen_fix \
    THUDM/chatglm3-6b \
    configs/lora.yaml
# Out:
# /home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Setting eos_token is not supported, use the default one.
# Setting pad_token is not supported, use the default one.
# Setting unk_token is not supported, use the default one.
# Loading checkpoint shards: 100%|██████████████████| 7/7 [00:03<00:00,  1.85it/s]
# trainable params: 1,949,696 || all params: 6,245,533,696 || trainable%: 0.0312
# --> Model
#
# --> model has 1.949696M params
#
# train_dataset: Dataset({
#     features: ['input_ids', 'labels'],
#     num_rows: 114599
# })
# val_dataset: Dataset({
#     features: ['input_ids', 'output_ids'],
#     num_rows: 1070
# })
# test_dataset: Dataset({
#     features: ['input_ids', 'output_ids'],
#     num_rows: 1070
# })
# --> Sanity check
#            '[gMASK]': 64790 -> -100
#                'sop': 64792 -> -100
#           '<|user|>': 64795 -> -100
#                   '': 30910 -> -100
#                 '\n': 13 -> -100
#                   '': 30910 -> -100
#                 '类型': 33467 -> -100
#                  '#': 31010 -> -100
#                  '裤': 56532 -> -100
#                  '*': 30998 -> -100
#                  '版': 55090 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                 '宽松': 40833 -> -100
#                  '*': 30998 -> -100
#                 '风格': 32799 -> -100
#                  '#': 31010 -> -100
#                 '性感': 40589 -> -100
#                  '*': 30998 -> -100
#                 '图案': 37505 -> -100
#                  '#': 31010 -> -100
#                 '线条': 37216 -> -100
#                  '*': 30998 -> -100
#                  '裤': 56532 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                  '阔': 56529 -> -100
#                  '腿': 56158 -> -100
#                  '裤': 56532 -> -100
#      '<|assistant|>': 64796 -> -100
#                   '': 30910 -> 30910
#                 '\n': 13 -> 13
#                   '': 30910 -> 30910
#                 '宽松': 40833 -> 40833
#                  '的': 54530 -> 54530
#                  '阔': 56529 -> 56529
#                  '腿': 56158 -> 56158
#                  '裤': 56532 -> 56532
#                  '这': 54551 -> 54551
#                 '两年': 33808 -> 33808
#                 '真的': 32041 -> 32041
#                  '吸': 55360 -> 55360
#                  '粉': 55486 -> 55486
#                 '不少': 32138 -> 32138
#                  '，': 31123 -> 31123
#                 '明星': 32943 -> 32943
#                 '时尚': 33481 -> 33481
#                  '达': 54880 -> 54880
#                 '人的': 31664 -> 31664
#                 '心头': 46565 -> 46565
#                  '爱': 54799 -> 54799
#                  '。': 31155 -> 31155
#                 '毕竟': 33051 -> 33051
#                  '好': 54591 -> 54591
#                  '穿': 55432 -> 55432
#                 '时尚': 33481 -> 33481
#                  '，': 31123 -> 31123
#                  '谁': 55622 -> 55622
#                 '都能': 32904 -> 32904
#                  '穿': 55432 -> 55432
#                  '出': 54557 -> 54557
#                  '腿': 56158 -> 56158
#                  '长': 54625 -> 54625
#                  '2': 30943 -> 30943
#                  '米': 55055 -> 55055
#                '的效果': 35590 -> 35590
#                 '宽松': 40833 -> 40833
#                  '的': 54530 -> 54530
#                  '裤': 56532 -> 56532
#                  '腿': 56158 -> 56158
#                  '，': 31123 -> 31123
#                '当然是': 48466 -> 48466
#                  '遮': 57148 -> 57148
#                  '肉': 55343 -> 55343
#                  '小': 54603 -> 54603
#                 '能手': 49355 -> 49355
#                  '啊': 55674 -> 55674
#                  '。': 31155 -> 31155
#                 '上身': 51605 -> 51605
#                  '随': 55119 -> 55119
#                  '性': 54642 -> 54642
#                 '自然': 31799 -> 31799
#                  '不': 54535 -> 54535
#                  '拘': 57036 -> 57036
#                  '束': 55625 -> 55625
#                  '，': 31123 -> 31123
#                 '面料': 46839 -> 46839
#                  '亲': 55113 -> 55113
#                  '肤': 56089 -> 56089
#                 '舒适': 33894 -> 33894
#                  '贴': 55778 -> 55778
#                 '身体': 31902 -> 31902
#                  '验': 55017 -> 55017
#                  '感': 54706 -> 54706
#                  '棒': 56382 -> 56382
#                  '棒': 56382 -> 56382
#                  '哒': 59230 -> 59230
#                  '。': 31155 -> 31155
#                  '系': 54712 -> 54712
#                  '带': 54882 -> 54882
#                 '部分': 31726 -> 31726
#                 '增加': 31917 -> 31917
#                 '设计': 31735 -> 31735
#                 '看点': 45032 -> 45032
#                  '，': 31123 -> 31123
#                  '还': 54656 -> 54656
#                  '让': 54772 -> 54772
#                 '单品': 46539 -> 46539
#                '的设计': 34481 -> 34481
#                  '感': 54706 -> 54706
#                 '更强': 43084 -> 43084
#                  '。': 31155 -> 31155
#                 '腿部': 46799 -> 46799
#                 '线条': 37216 -> 37216
#                  '若': 55351 -> 55351
#                  '隐': 55733 -> 55733
#                  '若': 55351 -> 55351
#                  '现': 54600 -> 54600
#                  '的': 54530 -> 54530
#                  '，': 31123 -> 31123
#                 '性感': 40589 -> 40589
#                  '撩': 58521 -> 58521
#                  '人': 54533 -> 54533
#                  '。': 31155 -> 31155
#                 '颜色': 33692 -> 33692
#                  '敲': 57004 -> 57004
#                 '温柔': 34678 -> 34678
#                  '的': 54530 -> 54530
#                  '，': 31123 -> 31123
#                  '与': 54619 -> 54619
#                 '裤子': 44722 -> 44722
#                 '本身': 32754 -> 32754
#                  '所': 54626 -> 54626
#                 '呈现': 33169 -> 33169
#                '的风格': 48084 -> 48084
#                 '有点': 33149 -> 33149
#                  '反': 54955 -> 54955
#                  '差': 55342 -> 55342
#                  '萌': 56842 -> 56842
#                  '。': 31155 -> 31155
#                   '': 2 -> 2
# max_steps is given, it will override any value given in num_train_epochs
# /home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ***** Running training *****
#   Num examples = 114,599
#   Num Epochs = 1
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 4
#   Total optimization steps = 5,000
#   Number of trainable parameters = 1,949,696
# {'loss': 4.0998, 'grad_norm': 3.380974531173706, 'learning_rate': 4.9e-05, 'epoch': 0.0}
# {'loss': 3.6487, 'grad_norm': 4.439432621002197, 'learning_rate': 4.8e-05, 'epoch': 0.01}
# {'loss': 3.5529, 'grad_norm': 6.000630855560303, 'learning_rate': 4.7e-05, 'epoch': 0.01}
# {'loss': 3.4896, 'grad_norm': 5.767866134643555, 'learning_rate': 4.600000000000001e-05, 'epoch': 0.01}
# {'loss': 3.4916, 'grad_norm': 5.88190221786499, 'learning_rate': 4.5e-05, 'epoch': 0.02}
#  10%|███▊                                  | 500/5000 [07:40<1:11:34,  1.05it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:07<00:07,  3.81s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:15<00:05,  5.40s/it]
# 100%|█████████████████████████████████████████████| 4/4 [00:46<00:00, 15.18s/it]Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.641 seconds.
# Prefix dict has been built successfully.
#
# {'eval_rouge-1': 31.963274000000002, 'eval_rouge-2': 7.109204, 'eval_rouge-l': 24.637954, 'eval_bleu-4': 0.03375192075345029, 'eval_runtime': 55.7496, 'eval_samples_per_second': 0.897, 'eval_steps_per_second': 0.072, 'epoch': 0.02}
#  10%|███▊                                  | 500/5000 [08:36<1:11:34,  1.05it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:47<00:00, 15.18s/it]
#                                                                                 Saving model checkpoint to /ssdData/llm/peft/models/chatglm3_2/chatglm3-6b/checkpoint-500
# /home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /ssdData/huggingface/cache/hub/models--THUDM--chatglm3-6b/snapshots/67d005d386a01d4825649743f41e90f83edd6094/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 3.4784, 'grad_norm': 6.260074138641357, 'learning_rate': 4.4000000000000006e-05, 'epoch': 0.02}
# {'loss': 3.4324, 'grad_norm': 6.089513301849365, 'learning_rate': 4.3e-05, 'epoch': 0.02}
# {'loss': 3.4608, 'grad_norm': 7.080866813659668, 'learning_rate': 4.2e-05, 'epoch': 0.03}
# {'loss': 3.3932, 'grad_norm': 8.121105194091797, 'learning_rate': 4.1e-05, 'epoch': 0.03}
# {'loss': 3.4293, 'grad_norm': 8.353216171264648, 'learning_rate': 4e-05, 'epoch': 0.03}
#  20%|███████▍                             | 1000/5000 [16:24<1:01:29,  1.08it/s]/home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:06<00:06,  3.30s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:12<00:04,  4.46s/it]
#
# {'eval_rouge-1': 32.417916, 'eval_rouge-2': 6.720916000000001, 'eval_rouge-l': 25.655496000000003, 'eval_bleu-4': 0.033283367024587014, 'eval_runtime': 22.4555, 'eval_samples_per_second': 2.227, 'eval_steps_per_second': 0.178, 'epoch': 0.03}
#  20%|███████▍                             | 1000/5000 [16:47<1:01:29,  1.08it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:16<00:00,  4.00s/it]
#                                                                                 Saving model checkpoint to /ssdData/llm/peft/models/chatglm3_2/chatglm3-6b/checkpoint-1000
# /home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /ssdData/huggingface/cache/hub/models--THUDM--chatglm3-6b/snapshots/67d005d386a01d4825649743f41e90f83edd6094/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 3.4447, 'grad_norm': 6.315907001495361, 'learning_rate': 3.9000000000000006e-05, 'epoch': 0.04}
# {'loss': 3.3798, 'grad_norm': 6.416352272033691, 'learning_rate': 3.8e-05, 'epoch': 0.04}
# {'loss': 3.3621, 'grad_norm': 7.372295379638672, 'learning_rate': 3.7e-05, 'epoch': 0.05}
# {'loss': 3.3838, 'grad_norm': 6.635181427001953, 'learning_rate': 3.6e-05, 'epoch': 0.05}
# {'loss': 3.355, 'grad_norm': 6.813904285430908, 'learning_rate': 3.5e-05, 'epoch': 0.05}
#  30%|███████████▋                           | 1500/5000 [24:35<50:36,  1.15it/s]/home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:08<00:08,  4.07s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:14<00:05,  5.13s/it]
#
# {'eval_rouge-1': 32.755006, 'eval_rouge-2': 6.944518, 'eval_rouge-l': 25.527852000000003, 'eval_bleu-4': 0.03445947672172697, 'eval_runtime': 27.0209, 'eval_samples_per_second': 1.85, 'eval_steps_per_second': 0.148, 'epoch': 0.05}
#  30%|███████████▋                           | 1500/5000 [25:02<50:36,  1.15it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:19<00:00,  4.75s/it]
#                                                                                 Saving model checkpoint to /ssdData/llm/peft/models/chatglm3_2/chatglm3-6b/checkpoint-1500
# /home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /ssdData/huggingface/cache/hub/models--THUDM--chatglm3-6b/snapshots/67d005d386a01d4825649743f41e90f83edd6094/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 3.4152, 'grad_norm': 6.950622081756592, 'learning_rate': 3.4000000000000007e-05, 'epoch': 0.06}
# {'loss': 3.3775, 'grad_norm': 6.719282627105713, 'learning_rate': 3.3e-05, 'epoch': 0.06}
# {'loss': 3.396, 'grad_norm': 7.6699748039245605, 'learning_rate': 3.2000000000000005e-05, 'epoch': 0.06}
# {'loss': 3.3751, 'grad_norm': 7.464535713195801, 'learning_rate': 3.1e-05, 'epoch': 0.07}
# {'loss': 3.3665, 'grad_norm': 7.7556843757629395, 'learning_rate': 3e-05, 'epoch': 0.07}
#  40%|███████████████▌                       | 2000/5000 [32:50<45:37,  1.10it/s]/home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:09<00:09,  4.64s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:15<00:05,  5.18s/it]
#
# {'eval_rouge-1': 31.069976, 'eval_rouge-2': 6.944788, 'eval_rouge-l': 24.092116, 'eval_bleu-4': 0.03310659160529855, 'eval_runtime': 95.0209, 'eval_samples_per_second': 0.526, 'eval_steps_per_second': 0.042, 'epoch': 0.07}
#  40%|███████████████▌                       | 2000/5000 [34:25<45:37,  1.10it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:46<00:00, 15.02s/it]
#                                                                                 Saving model checkpoint to /ssdData/llm/peft/models/chatglm3_2/chatglm3-6b/checkpoint-2000
# /home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /ssdData/huggingface/cache/hub/models--THUDM--chatglm3-6b/snapshots/67d005d386a01d4825649743f41e90f83edd6094/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 3.4122, 'grad_norm': 7.819258689880371, 'learning_rate': 2.9e-05, 'epoch': 0.07}
# {'loss': 3.3879, 'grad_norm': 6.963249206542969, 'learning_rate': 2.8000000000000003e-05, 'epoch': 0.08}
# {'loss': 3.3684, 'grad_norm': 7.776069164276123, 'learning_rate': 2.7000000000000002e-05, 'epoch': 0.08}
# {'loss': 3.3386, 'grad_norm': 7.379530906677246, 'learning_rate': 2.6000000000000002e-05, 'epoch': 0.08}
# {'loss': 3.3536, 'grad_norm': 9.15522289276123, 'learning_rate': 2.5e-05, 'epoch': 0.09}
#  50%|███████████████████▌                   | 2500/5000 [42:13<37:54,  1.10it/s]/home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:47<00:47, 23.88s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:53<00:16, 16.50s/it]
#
# {'eval_rouge-1': 31.556111999999995, 'eval_rouge-2': 6.6537, 'eval_rouge-l': 24.249342000000002, 'eval_bleu-4': 0.032306701292015384, 'eval_runtime': 133.5749, 'eval_samples_per_second': 0.374, 'eval_steps_per_second': 0.03, 'epoch': 0.09}
#  50%|███████████████████▌                   | 2500/5000 [44:26<37:54,  1.10it/s]
# 100%|█████████████████████████████████████████████| 4/4 [01:25<00:00, 22.11s/it]
#                                                                                 Saving model checkpoint to /ssdData/llm/peft/models/chatglm3_2/chatglm3-6b/checkpoint-2500
# /home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /ssdData/huggingface/cache/hub/models--THUDM--chatglm3-6b/snapshots/67d005d386a01d4825649743f41e90f83edd6094/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 3.3693, 'grad_norm': 8.550219535827637, 'learning_rate': 2.4e-05, 'epoch': 0.09}
# {'loss': 3.3792, 'grad_norm': 8.316460609436035, 'learning_rate': 2.3000000000000003e-05, 'epoch': 0.09}
# {'loss': 3.3254, 'grad_norm': 7.325945854187012, 'learning_rate': 2.2000000000000003e-05, 'epoch': 0.1}
# {'loss': 3.3745, 'grad_norm': 9.115087509155273, 'learning_rate': 2.1e-05, 'epoch': 0.1}
# {'loss': 3.3179, 'grad_norm': 7.286825180053711, 'learning_rate': 2e-05, 'epoch': 0.1}
#  60%|███████████████████████▍               | 3000/5000 [52:13<29:57,  1.11it/s]/home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:08<00:08,  4.23s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:54<00:21, 21.75s/it]
#
# {'eval_rouge-1': 31.304682000000007, 'eval_rouge-2': 6.813453999999999, 'eval_rouge-l': 23.630533999999997, 'eval_bleu-4': 0.030776417964933748, 'eval_runtime': 134.5697, 'eval_samples_per_second': 0.372, 'eval_steps_per_second': 0.03, 'epoch': 0.1}
#  60%|███████████████████████▍               | 3000/5000 [54:27<29:57,  1.11it/s]
# 100%|█████████████████████████████████████████████| 4/4 [01:26<00:00, 25.43s/it]
#                                                                                 Saving model checkpoint to /ssdData/llm/peft/models/chatglm3_2/chatglm3-6b/checkpoint-3000
# /home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /ssdData/huggingface/cache/hub/models--THUDM--chatglm3-6b/snapshots/67d005d386a01d4825649743f41e90f83edd6094/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 3.3346, 'grad_norm': 7.608681678771973, 'learning_rate': 1.9e-05, 'epoch': 0.11}
# {'loss': 3.3594, 'grad_norm': 8.199581146240234, 'learning_rate': 1.8e-05, 'epoch': 0.11}
# {'loss': 3.3544, 'grad_norm': 7.350768089294434, 'learning_rate': 1.7000000000000003e-05, 'epoch': 0.12}
# {'loss': 3.3263, 'grad_norm': 7.647548675537109, 'learning_rate': 1.6000000000000003e-05, 'epoch': 0.12}
# {'loss': 3.3101, 'grad_norm': 7.963006973266602, 'learning_rate': 1.5e-05, 'epoch': 0.12}
#  70%|█████████████████████████▉           | 3500/5000 [1:02:13<23:50,  1.05it/s]/home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:08<00:08,  4.12s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:13<00:04,  4.70s/it]
#
# {'eval_rouge-1': 33.334888, 'eval_rouge-2': 7.414318, 'eval_rouge-l': 26.000356, 'eval_bleu-4': 0.03645080158375566, 'eval_runtime': 25.1434, 'eval_samples_per_second': 1.989, 'eval_steps_per_second': 0.159, 'epoch': 0.12}
#  70%|█████████████████████████▉           | 3500/5000 [1:02:39<23:50,  1.05it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:18<00:00,  4.52s/it]
#                                                                                 Saving model checkpoint to /ssdData/llm/peft/models/chatglm3_2/chatglm3-6b/checkpoint-3500
# /home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /ssdData/huggingface/cache/hub/models--THUDM--chatglm3-6b/snapshots/67d005d386a01d4825649743f41e90f83edd6094/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 3.2905, 'grad_norm': 8.224675178527832, 'learning_rate': 1.4000000000000001e-05, 'epoch': 0.13}
# {'loss': 3.3295, 'grad_norm': 9.528496742248535, 'learning_rate': 1.3000000000000001e-05, 'epoch': 0.13}
# {'loss': 3.2813, 'grad_norm': 8.206412315368652, 'learning_rate': 1.2e-05, 'epoch': 0.13}
# {'loss': 3.3602, 'grad_norm': 8.476655006408691, 'learning_rate': 1.1000000000000001e-05, 'epoch': 0.14}
# {'loss': 3.3579, 'grad_norm': 9.136446952819824, 'learning_rate': 1e-05, 'epoch': 0.14}
#  80%|█████████████████████████████▌       | 4000/5000 [1:10:27<14:35,  1.14it/s]/home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:47<00:47, 23.92s/it]
#  75%|█████████████████████████████████▊           | 3/4 [01:34<00:33, 33.22s/it]
#
# {'eval_rouge-1': 32.827403999999994, 'eval_rouge-2': 7.045764, 'eval_rouge-l': 24.841347999999996, 'eval_bleu-4': 0.032751333044039245, 'eval_runtime': 147.3472, 'eval_samples_per_second': 0.339, 'eval_steps_per_second': 0.027, 'epoch': 0.14}
#  80%|█████████████████████████████▌       | 4000/5000 [1:12:55<14:35,  1.14it/s]
# 100%|█████████████████████████████████████████████| 4/4 [01:39<00:00, 22.66s/it]
#                                                                                 Saving model checkpoint to /ssdData/llm/peft/models/chatglm3_2/chatglm3-6b/checkpoint-4000
# /home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /ssdData/huggingface/cache/hub/models--THUDM--chatglm3-6b/snapshots/67d005d386a01d4825649743f41e90f83edd6094/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 3.314, 'grad_norm': 8.604350090026855, 'learning_rate': 9e-06, 'epoch': 0.14}
# {'loss': 3.3309, 'grad_norm': 8.193604469299316, 'learning_rate': 8.000000000000001e-06, 'epoch': 0.15}
# {'loss': 3.3121, 'grad_norm': 9.261547088623047, 'learning_rate': 7.000000000000001e-06, 'epoch': 0.15}
# {'loss': 3.2849, 'grad_norm': 8.527209281921387, 'learning_rate': 6e-06, 'epoch': 0.15}
# {'loss': 3.3046, 'grad_norm': 9.105061531066895, 'learning_rate': 5e-06, 'epoch': 0.16}
#  90%|█████████████████████████████████▎   | 4500/5000 [1:20:44<08:00,  1.04it/s]/home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:07<00:07,  3.65s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:53<00:21, 21.37s/it]
#
# {'eval_rouge-1': 33.378494, 'eval_rouge-2': 7.572932, 'eval_rouge-l': 24.469806, 'eval_bleu-4': 0.03328058970683996, 'eval_runtime': 105.6363, 'eval_samples_per_second': 0.473, 'eval_steps_per_second': 0.038, 'epoch': 0.16}
#  90%|█████████████████████████████████▎   | 4500/5000 [1:22:30<08:00,  1.04it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:57<00:00, 14.84s/it]
#                                                                                 Saving model checkpoint to /ssdData/llm/peft/models/chatglm3_2/chatglm3-6b/checkpoint-4500
# /home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /ssdData/huggingface/cache/hub/models--THUDM--chatglm3-6b/snapshots/67d005d386a01d4825649743f41e90f83edd6094/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 3.3023, 'grad_norm': 9.857086181640625, 'learning_rate': 4.000000000000001e-06, 'epoch': 0.16}
# {'loss': 3.3734, 'grad_norm': 9.49142837524414, 'learning_rate': 3e-06, 'epoch': 0.16}
# {'loss': 3.3458, 'grad_norm': 9.705345153808594, 'learning_rate': 2.0000000000000003e-06, 'epoch': 0.17}
# {'loss': 3.3052, 'grad_norm': 9.553542137145996, 'learning_rate': 1.0000000000000002e-06, 'epoch': 0.17}
# {'loss': 3.2794, 'grad_norm': 8.190678596496582, 'learning_rate': 0.0, 'epoch': 0.17}
# 100%|█████████████████████████████████████| 5000/5000 [1:30:15<00:00,  1.12it/s]/home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:07<00:07,  3.89s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:54<00:21, 21.61s/it]
#
# {'eval_rouge-1': 32.433482, 'eval_rouge-2': 6.909748, 'eval_rouge-l': 24.89314, 'eval_bleu-4': 0.033088626599638696, 'eval_runtime': 106.7545, 'eval_samples_per_second': 0.468, 'eval_steps_per_second': 0.037, 'epoch': 0.17}
# 100%|█████████████████████████████████████| 5000/5000 [1:32:02<00:00,  1.12it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:58<00:00, 15.17s/it]
#                                                                                 Saving model checkpoint to /ssdData/llm/peft/models/chatglm3_2/chatglm3-6b/checkpoint-5000
# /home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# loading configuration file config.json from cache at /ssdData/huggingface/cache/hub/models--THUDM--chatglm3-6b/snapshots/67d005d386a01d4825649743f41e90f83edd6094/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 5523.4435, 'train_samples_per_second': 3.621, 'train_steps_per_second': 0.905, 'train_loss': 3.38832314453125, 'epoch': 0.17}
# 100%|█████████████████████████████████████| 5000/5000 [1:32:03<00:00,  1.10s/it]
# /home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ***** Running Prediction *****
#   Num examples = 1070
#   Batch size = 16
# 100%|███████████████████████████████████████████| 67/67 [28:09<00:00, 25.21s/it]

# %% [markdown]
# ## 3. 使用微调的数据集进行推理
# 在完成微调任务之后，我们可以查看到 `output` 文件夹下多了很多个`checkpoint-*`的文件夹，这些文件夹代表了训练的轮数。
# 我们选择最后一轮的微调权重，并使用inference进行导入。

# %%
# !CUDA_VISIBLE_DEVICES=0 \
    NCCL_P2P_DISABLE="1" \
    NCCL_IB_DISABLE="1" \
    python inference_hf.py \
    /ssdData/llm/peft/models/chatglm3_2/chatglm3-6b/checkpoint-5000 \
    --prompt "类型#裙*版型#显瘦*材质#网纱*风格#性感*裙型#百褶*裙下摆#压褶*裙长#连衣裙*裙衣门襟#拉链*裙衣门襟#套头*裙款式#拼接*裙款式#拉链*裙款式#木耳边*裙款式#抽褶*裙款式#不规则"
# Out:
# /home/ubuntu/miniconda3/envs/chatglm3_311/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████████████| 7/7 [00:04<00:00,  1.69it/s]
# Setting eos_token is not supported, use the default one.
# Setting pad_token is not supported, use the default one.
# Setting unk_token is not supported, use the default one.
# 这款连衣裙采用压褶百褶的款式设计，不规则的裙摆造型，轻松遮肉显瘦，不挑人穿，不挑身形。采用网纱材质，打造性感小女人，整体采用套头式设计，方便穿脱，不拉拉链，不粘连。领口采用木耳边拼接，打造小女人，搭配拉链，方便穿脱。

# %% [markdown]
# ## 4. 总结
# 到此位置，我们就完成了使用单张 GPU Lora 来微调 ChatGLM3-6B 模型，使其能生产出更好的广告。
# 在本章节中，你将会学会：
# + 如何使用模型进行 Lora 微调
# + 微调数据集的准备和对齐
# + 使用微调的模型进行推理
